# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
GROQ_API_KEY=os.getenv("GROQ_API_KEY")
GOOGLE_API_KEY=os.getenv("GOOGLE_API_KEY")

# %%
os.environ["GROQ_API_KEY"]= GROQ_API_KEY
os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY

# %%
from langchain_groq import ChatGroq
llm1=ChatGroq(model_name="qwen/qwen3-32b")
llm2=ChatGroq(model_name="llama-3.1-8b-instant")

# %%
llm1.invoke("What is the capital of France?").content
# Out:
# '<think>\nOkay, the user is asking, "What is the capital of France?" Let me think. First, I need to confirm that France is a country in Europe. I remember from geography class that capitals are usually major cities. France\'s capital is a well-known city. Let me recall... Paris, right? I think Paris is the capital. But wait, maybe I should double-check to be sure. Sometimes countries have other major cities, like Lyon or Marseille, but the capital is usually the political and administrative center. Paris is where the government is located, so that must be the capital. I don\'t think there\'s any confusion here. Yeah, I\'m pretty confident the answer is Paris.\n</think>\n\nThe capital of France is **Paris**. It is the largest city in France and serves as the country\'s political, economic, and cultural center. Paris is also renowned for its historical landmarks, such as the Eiffel Tower, the Louvre Museum, and Notre-Dame Cathedral.'

# %%
llm2.invoke("What is the capital of France?").content
# Out:
# 'The capital of France is Paris.'

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm3 = ChatGoogleGenerativeAI(model="models/gemini-flash-latest")

# %%
llm3.invoke("What is the capital of France?").content
# Out:
# 'The capital of France is **Paris**.'
